# %% [markdown]
# <a href="https://colab.research.google.com/github/naijacr/Naija-ML-assigment-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/naijacr/Naija-ML-assigment-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *C## My Lane as an ML Task
#
# I chose the Content Refresh Prioritization lane. This is mainly a ranking problem because the goal is to rank web pages according to which ones should be refreshed first. Instead of simply classifying pages as good or bad, the model should prioritize pages based on their potential benefit from a content update.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *## Target or Proxy
#
# The target is the priority score for refreshing a page. Since there is no direct label showing which pages should be refreshed, a proxy target can be created using features such as impressions, click-through rate (CTR), average search position, traffic trend, and content age.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# ## Success Metric
#
# A successful model should correctly identify the pages that deserve a refresh before lower-priority pages. The recommendations should help improve search performance while reducing unnecessary work for the content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
# ## Unit of Analysis
#
# Each row in the dataset represents one web page. Each page contains SEO-related information such as impressions, CTR, search position, and content characteristics that can be used for prioritization.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)

df.head()
# Out:
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter

# %%
import os

os.chdir("/content/flyrank-ml-internship-starter")
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# %cd flyrank-ml-internship-starter
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 283 (delta 106), reused 78 (delta 78), pack-reused 147 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 11.44 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
import os
print(os.getcwd())
print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# True

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# ## Why ML Beats a Fixed Rule
#
# A simple rule such as refreshing every old page or every page with low CTR would ignore many important factors. Machine learning can consider multiple features together and discover patterns that are difficult to capture using manual rules. This allows better prioritization of pages that are most likely to benefit from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
