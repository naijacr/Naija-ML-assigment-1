# %% [markdown]
# <a href="https://colab.research.google.com/github/naijacr/Naija-ML-assigment-1/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/naijacr/Naija-ML-assigment-1/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# ## Unit of Analysis + Time Window
#
# One row represents one web page with its SEO performance metrics for a specific reporting period. I will use a mid-panel month (March 2026) so that the model learns from historical data without using the final month, which is reserved for evaluation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# ## Fields
#
# **Features**
# - Impressions
# - Click-through rate (CTR)
# - Average search position
# - Content age
# - Word count
#
# **Label / Proxy**
# - Refresh priority score or ranking of each page.
#
# **Context**
# - Month
# - Page identifier
#
# **Excluded**
# - Future traffic or ranking information after the refresh decision because it would leak future knowledge into the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# ## Verification
#
# The queries below verify the structure of the dataset, the number of records, the available fields, and whether important columns contain missing values. Viewing the first few rows confirms that each row represents one webpage with its associated SEO metrics.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show dataset size
print("Rows:", len(df))
print("Columns:", len(df.columns))

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# Display first few rows
print("\nSample data:")
display(df.head())
# Out:
# Rows: 30000
# Columns: 44
#
# Missing values:
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# sessions_prev_30d             0
# ...

# %%
import os

print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter

# %%
import os

print(os.listdir())
# Out:
# ['requirements.txt', 'skills', 'LICENSE', 'outputs', 'work', '.github', '.git', '.gitignore', 'CLAUDE.md', 'SETUP.md', 'data', 'docs', 'README.md', 'notebooks', 'AGENTS.md', 'GUIDE.md', 'scripts', 'submission', 'DATA_USE.md']

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./outputs/refresh_queue_sample.csv
# ./data/raw/content_refresh_anonymized.csv

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 283 (delta 106), reused 78 (delta 78), pack-reused 147 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
# %cd flyrank-ml-internship-starter
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import os

print(os.getcwd())
print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# True

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Data limits
#
# ## Data Limits
#
# This dataset only contains historical SEO information. It cannot explain why Google's rankings changed or prove that refreshing a page will increase traffic. External factors such as algorithm updates, seasonality, and competitor actions are not directly captured.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
